# %%
import pandas as pd
import csv

# %%
problemDF = pd.read_csv('problemInfo.csv', index_col=0, dtype=str)
problemDF = problemDF[['pId','successCnt']]
problemDF['successCnt'].type()
#print(problemDF[problemDF['successCnt'].isnull()])
# Out:
# 0           69
# 1           87
# 2           18
# 3            8
# 4           44
#          ...
# 9568       392
# 9569       391
# 9570       387
# 9571       958
# 9572    109553
# Name: successCnt, Length: 9573, dtype: object
