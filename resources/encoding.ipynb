# %%
r = open('D:/AlgorithmProblemRecommender/Recommenders/resources/results/20220521/test_data_0.01').read()

# %%
w = open('D:/AlgorithmProblemRecommender/Recommenders/resources/results/20220521/test_data_0.01','w',encoding='ANSI').write(r)
